# %%
# !pip install fredpy

# %%
import pandas as pd
import fredpy as fp
from datetime import datetime, timedelta
fp.api_key = '3e2ce012f9e6acc4881767aa75c9c0ee'

enddate=(datetime.now() + timedelta(days=-1)).strftime('%Y-%m-%d')
# 달러인덱스 symbol 'DTWEXBGS'
dol= fp.series('DTWEXBGS',enddate)
dol.data
# Out:
# date
# 2006-01-02    101.4155
# 2006-01-03    100.7558
# 2006-01-04    100.2288
# 2006-01-05    100.2992
# 2006-01-06    100.0241
#                 ...
# 2023-11-03    122.2337
# 2023-11-06    122.0962
# 2023-11-07    122.5100
# 2023-11-08    122.5279
# 2023-11-09    122.5677
# Freq: B, Name: value, Length: 4659, dtype: float64

# %% [markdown]
# # 달러인덱스
# - 세계 주요 6개 통화(유로, 일본 엔, 영국 파운드 스털링, 캐나다 달러, 스웨덴 크로나, 스위스 프랑)의 가치에 경제규모에 따라 비중을 달리하여 산출한 값을 미국 달러와 비교한 지표
# - 달러가 타 통화 대비 얼마나 비싼지 알려주는 지수
# - 달러인덱스 상승 => 미달러 가치 상승
# - 유로(57.6%)>엔>파운드>..순으로 비중 두기 때문에 유로화에 크게 좌우됨
#
# - 구리(산업) : 경기가 호황이면 가격 상승 경기가 불활이면 가격 하락
# - 금 :
# - 은 :

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # < 달러 인덱스 상승 이유 >
# - 실제로 달러의 가치 상승
# - 러 우 전쟁으로 인한 유럽 연합의 위기
# - 대부분의 나라가 금리인상을 하고 있는데도 금리 동결을 하고 있는 일본의 영향

# %% [markdown]
# ## 금, 은, 구리 데이터 수집을 위한 라이브러리 설치

# %%
# !pip install yfinance

# %%
import yfinance as yf
# 금,은, 구리데이터를 달러 인덱스 기간과 맞춰줌
gld=yf.download('GC=F', '2006-01-01', enddate, auto_adjust=True)
silv=yf.download('SI=F', '2006-01-01', enddate, auto_adjust=True)
hg=yf.download('HG=F', '2006-01-01', enddate, auto_adjust=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
gld
# 변수설명: 시가, 고가, 저가, 종가, 거래량
# Out:
#                    Open         High          Low        Close  Volume
# Date
# 2006-01-03   518.599976   528.500000   518.599976   530.700012       7
# 2006-01-04   533.599976   533.599976   533.500000   533.900024       8
# 2006-01-05   529.000000   529.000000   526.000000   526.299988      10
# 2006-01-06   539.700012   539.700012   539.700012   539.700012      10
# 2006-01-09   539.700012   539.700012   539.700012   549.099976      10
# ...                 ...          ...          ...          ...     ...
# 2023-11-06  1981.599976  1981.599976  1977.400024  1981.599976     130
# 2023-11-07  1966.500000  1966.800049  1960.699951  1966.800049      20
# 2023-11-08  1967.800049  1967.800049  1947.699951  1951.500000      43
# 2023-11-09  1951.699951  1964.199951  1945.300049  1964.199951      10
# 2023-11-10  1959.599976  1959.599976  1932.599976  1932.599976     375
#
# [4493 rows x 5 columns]

# %% [markdown]
# ## 달러인덱스와 금의 종가 추이

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=gld.index, y=gld['Close'], name="금"),
    secondary_y=False,
)


fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 달러인덱스와 은의 종가 추이

# %%
# 달러인덱스와 은
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=silv.index, y=silv['Close'], name="은"),
    secondary_y=False,
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 달러인덱스와 구리의 종가 추이

# %%
# 달러인덱스와 구리
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=hg.index, y=hg['Close'], name="구리"),
    secondary_y=False,
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 기준가 설정

# %%
gld['Close_change']=gld['Close'].pct_change()
# Close_change : 전날 종가 대비 등락률 ex) 0.006030 = (533.900024 - 530.700012) / 533.900024
gld['Close_changecum']=(1+gld['Close_change']).cumprod()
# Close_changecum : 첫날 기준 누적 등락률
gld.loc['2006-01-03','Close_changecum']=1
# 달러 인덱스의 2006-01-03의 데이터는 100.7558라 금도 동일하게 설정
gld['gld_index']=gld['Close_changecum']*100.7558
gld
# Out:
#                    Open         High          Low        Close  Volume  \
# Date
# 2006-01-03   518.599976   528.500000   518.599976   530.700012       7
# 2006-01-04   533.599976   533.599976   533.500000   533.900024       8
# 2006-01-05   529.000000   529.000000   526.000000   526.299988      10
# 2006-01-06   539.700012   539.700012   539.700012   539.700012      10
# 2006-01-09   539.700012   539.700012   539.700012   549.099976      10
# ...                 ...          ...          ...          ...     ...
# 2023-11-06  1981.599976  1981.599976  1977.400024  1981.599976     130
# 2023-11-07  1966.500000  1966.800049  1960.699951  1966.800049      20
# 2023-11-08  1967.800049  1967.800049  1947.699951  1951.500000      43
# 2023-11-09  1951.699951  1964.199951  1945.300049  1964.199951      10
# 2023-11-10  1959.599976  1959.599976  1932.599976  1932.599976     375
#
#             Close_change  Close_changecum   gld_index
# Date
# ...

# %%
silv['Close_change']=silv['Close'].pct_change()
silv['Close_changecum']=(1+silv['Close_change']).cumprod()
silv.loc['2006-01-03','Close_changecum']=1
silv['silv_index']=silv['Close_changecum']*100.7558

hg['Close_change']=hg['Close'].pct_change()
hg['Close_changecum']=(1+hg['Close_change']).cumprod()
hg.loc['2006-01-03','Close_changecum']=1
hg['hg_index']=hg['Close_changecum']*100.7558

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=gld.index, y=gld['gld_index'], name="금"),
    secondary_y=False,
)

fig.add_trace(
    go.Line(x=silv.index, y=silv['silv_index'], name="은"),
    secondary_y=False,
)


fig.add_trace(
    go.Line(x=hg.index, y=hg['hg_index'], name="구리"),
    secondary_y=False,
)

fig.update_layout(
    title_text='달러인덱스와 금,은,구리',
    title={'x':0.5, 'y':0.85}

)

fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 달러 가치오르면 금, 은, 구리
