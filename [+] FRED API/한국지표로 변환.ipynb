# %%
# !pip install fredpy

# %%
import warnings

# 경고메세지 끄기
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import fredpy as fp
from datetime import datetime, timedelta
fp.api_key = '3e2ce012f9e6acc4881767aa75c9c0ee'

# %%
df = pd.read_csv('/content/drive/MyDrive/ASAC/최종프로젝트/kr_finance_data.csv')
df
# Out:
#        연도  월   선행종합지수(2020=100) 　　　 재고순환지표(%p) 　　　 경제심리지수  \
# 0    1990  1               23.5              -          -
# 1    1990  2               23.7              -          -
# 2    1990  3               23.8              -          -
# 3    1990  4               24.0              -          -
# 4    1990  5               24.1              -          -
# ..    ... ..                ...            ...        ...
# 400  2023  5              109.8          -17.2       93.2
# 401  2023  6              110.5            -13       94.6
# 402  2023  7              111.1           -9.6       94.7
# 403  2023  8              111.4           -7.9       94.6
# 404  2023  9              111.8           -8.9       93.6
#
#     　　　 기계류내수출하지수(선박제외)(2020=100) 　　　 건설수주액(실질)(십억원) 　　　수출입물가비율(2015=100)  \
# 0                               -                  -                    -
# 1                               -                  -                    -
# ...

# %%
for i in range(9,405,12):
    df['월'][i] = 10

# %%
df['날짜'] =df['연도'].astype(str) +'-'+df['월'].astype(str)

# %%
df['날짜']
# Out:
# 0      1990-1
# 1      1990-2
# 2      1990-3
# 3      1990-4
# 4      1990-5
#         ...
# 400    2023-5
# 401    2023-6
# 402    2023-7
# 403    2023-8
# 404    2023-9
# Name: 날짜, Length: 405, dtype: object

# %%
df['날짜'] = pd.to_datetime(df['날짜'])

# %%
df['날짜']
# Out:
# 0     1990-01-01
# 1     1990-02-01
# 2     1990-03-01
# 3     1990-04-01
# 4     1990-05-01
#          ...
# 400   2023-05-01
# 401   2023-06-01
# 402   2023-07-01
# 403   2023-08-01
# 404   2023-09-01
# Name: 날짜, Length: 405, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   연도                              405 non-null    int64
#  1   월                               405 non-null    int64
#  2    선행종합지수(2020=100)               405 non-null    float64
#  3   　　　 재고순환지표(%p)                  405 non-null    object
#  4   　　　 경제심리지수                      405 non-null    object
#  5   　　　 기계류내수출하지수(선박제외)(2020=100)   405 non-null    object
#  6   　　　 건설수주액(실질)(십억원)              405 non-null    object
#  7   　　　수출입물가비율(2015=100)            405 non-null    object
#  8   　　　코스피(1980.1.4=100)            405 non-null    object
#  9   　　　 장단기금리차(%p)                  405 non-null    object
#  10   동행종합지수(2020=100)               405 non-null    float64
#  11  　　　 광공업생산지수(2020=100)           405 non-null    object
# ...

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # 실업률과 경기침체

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

# 연도 조건을 걸어 데이터를 필터링
condition = (df['연도'] >= 1998)
filtered_df = df[condition]

# Add traces
fig.add_trace(
    go.Line(x=filtered_df['연도'], y=filtered_df['실업률총계'], name="실업률"),
    secondary_y=True,
)

fig.add_trace(
    go.Bar(x=filtered_df['연도'], y=filtered_df['경제위기'], name="경기침체"),
    secondary_y=False,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 경제위기
#     - 1998 : IMF
#     - 2003: 카드 대출 부실
#     - 2008: 글로벌 금융위기
#     - 2020~2022: 코로나
# - 특히 코로나 시기에 실업률 급증하는 경향

# %% [markdown]
# # 소비자 물가지수
# - 일상행활에서 소비되는 다양한 상품과 서비스의 가격변화 측정하는 지표
# - 인플레이션 측정 가능
# - cpi상승 = 각종 상품, 서비스 가격 상승

# %%
from datetime import datetime, timedelta

enddate=(datetime.now() + timedelta(days=-1)).strftime('%Y-%m-%d')
cpi=(df['소비자물가지수'],enddate)

# %%
plt.figure(figsize=(16,6) )
sns.barplot(data=df,x='연도',y='소비자물가지수')
plt.show()

# %% [markdown]
# ## yoy(1년전 같은 달 대비 성장)
# - fred지표만 사용가능 함수라 적용 아직

# %% [markdown]
# ## mom(지난달 대비 성장)

# %%
df['cpimom'] = df['소비자물가지수'].pct_change()*100

# %%
fig=px.bar(x=df['날짜'], y=df['cpimom'], color=df['cpimom'],
          title='CPI MOM 장기데이터', height=500)
fig.update_traces(textposition='outside')
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 경제위기시 물가 상승 이유
# - 환율 상승: 외환위기로 인해 원화 가치가 급격히 하락(원화 가치가 하락하면 수입품 가격이 상승)
#
# - 공급 감소: 기업들이 대규모로 부도를 내면서 생산량이 감소

# %% [markdown]
# IMF사태 -> 1998년도에는 물가가 크게 상승
#
# 1999년도에는 환율도 하향 조정, 많은 기업들이 본격적으로 파산 & 대규모 실직
#
# -> 우리나라 경제 전반이 매우 크게 침체 -> 소비가 크게 감소 -> 물가 감소

# %% [markdown]
# # 근원소비자 물가지수

# %% [markdown]
# - 농산물및석유류제외지수

# %%
plt.figure( figsize=(16,6) )
sns.barplot(data=df,x='연도',y='농산물및석유류제외지수')
plt.show()

# %%
df['corecpimom1']=df['농산물및석유류제외지수'].pct_change()*100

# %%
fig=px.bar(x=df['날짜'], y=df['corecpimom1'], color=df['corecpimom1'],
          title='농산물및석유류제외지수 MOM 장기데이터', height=500)
fig.update_traces(textposition='outside')
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - 식료품 및 에너지제외 지수

# %%
plt.figure( figsize=(16,6) )
sns.barplot(data=df,x='연도',y='식료품 및 에너지제외 지수')
plt.show()

# %%
df['corecpimom2']=df['식료품 및 에너지제외 지수'].pct_change()*100

# %%
fig=px.bar(x=df['날짜'], y=df['corecpimom2'], color=df['corecpimom2'],
          title='식료품 및 에너지제외 지수 MOM 장기데이터', height=500)
fig.update_traces(textposition='outside')
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

usreg = fp.series('USREC',enddate)
usregdata=usreg.data.loc[usreg.data.index>='1945-01-01']

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=df['날짜'], y=df['소비자물가지수'], name="소비자물가지수"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=df['날짜'], y=df['cpimom'], name="소비자물가지수 지난달 대비 성장률"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=df['날짜'], y=df['corecpimom1'], name="농산물및석유류제외지수 지난달 대비 성장률"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=df['날짜'], y=df['corecpimom2'], name=" 식료품 및 에너지제외 지수 지난달 대비 성장률"),
    secondary_y=True,
)

fig.add_trace(
    go.Bar(x=df['날짜'], y=df['경제위기'], name="경기침체"),
    secondary_y=False,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig=px.line(data_frame=df, x='날짜', y=['cpimom','corecpimom1', 'corecpimom2'],
          title='CPI vs CoreCPI MOM 장기데이터', height=500)
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 원 달러 환율의 symbol은 'DEXKOUS'
# - 일별 > 한달 평균내서

# %%
won= fp.series('DEXKOUS',enddate)
won.data[5000:]
# Out:
# date
# 2000-06-12    1113.40
# 2000-06-13    1114.40
# 2000-06-14    1114.50
# 2000-06-15    1115.00
# 2000-06-16    1116.40
#                ...
# 2023-11-03    1322.04
# 2023-11-06    1297.94
# 2023-11-07    1308.33
# 2023-11-08    1309.98
# 2023-11-09    1309.89
# Freq: B, Name: value, Length: 6109, dtype: float64

# %%
enddate=(datetime.now() + timedelta(days=-1)).strftime('%Y-%m-%d')
df['won']= fp.series('DEXKOUS',enddate).data
df
# Out:
#        연도  월   선행종합지수(2020=100) 　　　 재고순환지표(%p) 　　　 경제심리지수  \
# 0    1990  1               23.5              -          -
# 1    1990  2               23.7              -          -
# 2    1990  3               23.8              -          -
# 3    1990  4               24.0              -          -
# 4    1990  5               24.1              -          -
# ..    ... ..                ...            ...        ...
# 400  2023  5              109.8          -17.2       93.2
# 401  2023  6              110.5            -13       94.6
# 402  2023  7              111.1           -9.6       94.7
# 403  2023  8              111.4           -7.9       94.6
# 404  2023  9              111.8           -8.9       93.6
#
#     　　　 기계류내수출하지수(선박제외)(2020=100) 　　　 건설수주액(실질)(십억원) 　　　수출입물가비율(2015=100)  \
# 0                               -                  -                    -
# 1                               -                  -                    -
# ...

# %% [markdown]
# ## 달러 인덱스

# %%
enddate=(datetime.now() + timedelta(days=-1)).strftime('%Y-%m-%d')
dol= fp.series('DTWEXBGS',enddate)
dol.data

# %% [markdown]
# ## 데이터의 기간을 맞추기 위해 원 달러 환율의 기간을 '2006-01-02'

# %%
wondata=won.data.loc[won.data.index > '2006-01-02']

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=dol.data.index, y=dol.data.values, name="달러인덱스"),
    secondary_y=True,
)

fig.add_trace(
    go.Line(x=wondata.index, y=wondata.values, name="원달러환율"),
    secondary_y=False,
)

#fig.add_trace(
#    go.Bar(x=usregdata.index, y=usregdata.values, name="경기침체"),
#    secondary_y=False,
#)

fig.show()

# %%
# 그래프 유사
# 코로나, 리먼브라더스 사태(2008) 때 둘다 증가
# 리먼브라더스 : 미국의 대형 투자은행이 파산한 사건
# 미국에 투자되었던 자본은 외부로 유출되고, 투자심리 악화 -> 불황 -> 실업률 증가
# 달러 상승 = 유동성 회수하려는 움직임, 시중에 통화 많이 풀림, 거둬들이려고 가격이 오름
# 연준은 경기부양을 위해 금리 인하를 단행

# %% [markdown]
# ## 원 달러 환율과 달러 인덱스의 차분 그래프 확인

# %%
df=pd.concat([dol.data,wondata], axis=1)
df.columns=['달러인덱스','원달러환율']
df

# %%
df['원달러환율_change']=df['원달러환율'].pct_change()
df['원달러환율_changecum']=(1+df['원달러환율_change']).cumprod()

# %%
df.loc['2006-01-03','원달러환율_changecum']=1
df['원달러환율index']=df['원달러환율_changecum']*100.7558

# %%
df['차분']=df['원달러환율index']-df['달러인덱스']
df

# %%
import plotly.express as px

fig=px.line(data_frame=df, x=df.index, y='차분',
          title='원 달러 인덱스와 달러인덱스의 차분 그래프', height=500)
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()

# %%
# 하락상승 리만 브라더스
# 코로나 시기 후 다시 상승 중

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# NBER 경기 침체 데이터 symbol은 'USREC'
usreg = fp.series('USREC',enddate)
usregdata=usreg.data.loc[usreg.data.index>='2006-01-01']

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=df.index, y=df['차분']),
    secondary_y=True,
)

fig.add_trace(
    go.Bar(x=usregdata.index, y=usregdata.values, name="경기침체"),
    secondary_y=False,
)

fig.show()

# %%
enddate='2022-11-23'
u = fp.series('UNRATE',enddate)

usreg = fp.series('USREC',enddate)
usreg.data

udata=u.data.loc[u.data.index>='1980-01-01']
udata

usregdata=usreg.data.loc[usreg.data.index>='1980-01-01']
usregdata

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Line(x=udata.index, y=udata.values, name="실업률"),
    secondary_y=True,
)

fig.add_trace(
    go.Bar(x=usregdata.index, y=usregdata.values, name="경기침체"),
    secondary_y=False,
)

fig.show()

# %% [markdown]
# ## 소비자 물가 지수 CPI의 Symbol은 'CPIAUCSL'이고 Core CPI는 'CPILFESL'입니다.

# %% [markdown]
# - CPI: 일상행활에서 소비되는 다양한 상품과 서비스의 가격변화 측정하는 지표
#     - 식료품, 주택, 교통, 의료, 교육 등 모든 카테고리 포함

# %% [markdown]
# - core CPI(근원소비자 물가지수)
#     - 변동성이 큰 항목(에너지, 식품) 제외한 지표
#     - 장기적인 물가흐름 파악

# %%
from datetime import datetime, timedelta

enddate=(datetime.now() + timedelta(days=-1)).strftime('%Y-%m-%d')
cpi= fp.series('CPIAUCSL',enddate)
corecpi = fp.series('CPILFESL',enddate)
cpi.data

# %%
cpiyoy=cpi.apc().data
cpiyoy

# %% [markdown]
# ## 이번에는 MOM(지난달 대비 성장)을 확인해 보겠습니다.
# ## fredpy에서는 별도로 지원은 없고 pct_change로 간단히 계산이 됩니다.

# %%
cpimom=cpi.data.pct_change()*100
cpimom

# %%
corecpiyoy=corecpi.apc().data
corecpimom=corecpi.data.pct_change()*100

# %% [markdown]
# ## 그래프로 확인

# %%
import plotly.express as px

fig=px.bar(x=cpiyoy.index, y=cpiyoy.values, color=cpiyoy.values,
          title='CPI YOY 장기데이터', height=500)
fig.update_traces(textposition='outside')
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()

# %% [markdown]
# ## CPI MOM LongTerm Data

# %%
fig=px.bar(x=cpimom.index, y=cpimom.values, color=cpimom.values,
          title='CPI MOM 장기데이터', height=500)
fig.update_traces(textposition='outside')
fig.update_layout(
    uniformtext_minsize=8, uniformtext_mode='hide',
    title={
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
fig.show()

# %% [markdown]
# ## Core CPI 근원 소비자물가지수란 소비자물가지수(CPI)에서 식품과 에너지 가격을 제외하고 측정한 지수

# %%
# 소비자물가지수, 실업률 등 -> 우리나라로 변환!
# 상품정보로만은 근거 부족
# 거시적 데이터도 포함

# 생명보험, 실비보험 해지율 높음 <- 경기 침체 시그널?
# 예적금 이탈률도 높음
# 상품 추천 전 현재 경제상황 파악 필요, 근본적인 트렌드 추이

## 총정리: 소비자물가지수 , 원달러 환율, 실업률(우리나라 기반), 보험 해지율 등 --> 적합한 시중은행 상품이 무엇일지?
# 본원물가지수(소비자물가지수에서 특정 몇개 제외함), 소비자묽지수 구별

# %% [markdown]
# - 경기침체 데이터(미국은 USREC)
# - 실업률(=>고용보험 가입률로 대체)
# - 소비자물가지수, cpi
#
# - 근원물가지수(소비자물가지수에서 변동성 큰 항목 제외), core cpi
#     - mom(지난달 대비 성장 <= cpi.pct_change)
# 	- YOY(1년 전 같은 달에서의 성장 <=corecpi.apc() )

# %% [markdown]
# # 소비자물가지수, cpi
# - https://ko.tradingeconomics.com/south-korea/consumer-price-index-cpi#calendar-table
# - https://www.index.go.kr/unify/idx-info.do?idxCd=4226
# - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1J20001&checkFlag=N
# - https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=1060  ??

# %% [markdown]
# # 근원물가지수, core cpi
# - https://ko.tradingeconomics.com/south-korea/consumer-price-index-cpi#calendar-table (핵심물가지수)

# %% [markdown]
# 1. 농산물 및 석유류 제외 지수​​
#
# 전체 소비자물가지수 집계 시 포함되는 458개 품목 중
# 농산물(곡물 제외)과 석유류 관련 품목을 뺀 401개 품목
# 물가의 기조 흐름을 보여주면서도 민생 물가와 더 맞닿아 있다는 장점
#
#
# 2. 식료품 및 에너지 제외 지수
#
# 수산물과 축산물, 가스와 전기 요금 등을 제외한 309개 품목의 가격만 집계
#
# 곡물가격은 채소 등에 비해 비축미 등을 통해 공급 조절이 가능한 점을 고려해 농산물 및 석유류 제외 지수에서는 예외적으로 집계 품목에 포함되지만, 식료품 및 에너지 제외 지수에서는 제외된다.
#
# 경제협력개발기구(OECD)가 인정하는 근원물가지수다. 국제간 비교 가능

# %% [markdown]
# # 기준금리
# https://ecos.bok.or.kr/#/SearchStat
